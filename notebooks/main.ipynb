# %%
# %run setup.py
# Out:
# Setup done ✔
# Current dir: C:\projects\data-Inspector

# %%
import main
# %run main.py
# Out:
# Loading data...
# Running coverage metrics...
# Running noise metrics...
# Running integrity metrics...
# Running duplicate metrics...
#
#
# ############################################################
# DATA QUALITY REPORT
# ############################################################
#
# ...
# COVERAGE
# ...
# % moyen de couverture des étudiants                     : 87.0%
# % étudiants avec couverture ≥ 80%                       : 100.0%
# % étudiants avec couverture < 50%                       : 0.0%
# % moyen de densité de couverture par matière            : 87.0%
# % moyen de couverture des matières                      : 87.0%
# % moyen de densité de couverture par trimestre          : 87.0%
# % couverture globale                                    : 87.0%
# % couverture (étudiant, matière)                        : 100.0%
# % couverture (étudiant, trimestre)                      : 100.0%
#
# ...
# NOISE
# ...
# % notes NULL                                            : 10.03%
# ...
