# %%
# %run setup.py
# Out:
# Setup done ✔
# Current dir: C:\projects\data-Inspector

# %%
from src.metrics.duplicates import calculate_duplicate_metrics
res = calculate_duplicate_metrics(data)
res
# Out:
# {'% duplication PK étudiants': np.float64(0.0),
#  '% duplication PK enseignement': np.float64(0.0),
#  '% duplication PK évaluations': np.float64(0.0),
#  '% duplication métier enseignement': np.float64(0.32),
#  '% duplication métier évaluations': np.float64(0.0),
#  '% duplication étudiant (nom + user)': np.float64(0.0),
#  '% duplication user étudiant': np.float64(0.0)}

# %%
import google.generativeai as genai

# configuration du modèle
genai.configure(api_key=api_key)

model = genai.GenerativeModel("gemini-3-flash-preview")

# prompt
prompt = f"""
Vous êtes un expert en qualité des données et en systèmes BI.

Analysez les métriques de duplication suivantes issues d’un processus
d’inspection d’un dataset scolaire.

Métriques :
{res}

Votre mission :
- Interpréter chaque métrique de duplication
- Expliquer ce que signifient des taux élevés ou faibles
- Identifier les risques de corruption logique des données
- Expliquer les impacts possibles sur BI, reporting et agrégations
- Détecter les problèmes de modélisation (clé primaire, clé métier)
- Proposer des pistes de correction ou de nettoyage

Contexte :
Ce dataset est utilisé pour l’analyse des performances des étudiants
(notes, évaluations, moyennes, enseignement).

Format attendu :

1. Évaluation générale de la duplication
2. Analyse des duplications techniques (PK)
3. Analyse des duplications métier (business logic)
4. Risques pour les analyses et les KPI
5. Recommandations de correction
"""

# génération de l'interprétation
response = model.generate_content(prompt)

# affichage du résultat
print(response.text)
# Out:
# C:\Users\adems\AppData\Local\Temp\ipykernel_11532\3841041156.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# En tant qu'expert en qualité des données et systèmes BI, voici mon analyse détaillée des métriques de duplication de votre dataset scolaire.
#
# ---
#
# ### 1. Évaluation générale de la duplication
# Le dataset présente un **excellent niveau de santé technique**. L'absence totale de doublons sur les clés primaires (PK) indique une base solide et un processus d'ingestion (ETL) bien maîtrisé.
#
# ...
