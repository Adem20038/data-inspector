# %%
# %run setup.py
# Out:
# Setup done ✔
# Current dir: C:\projects\data-Inspector

# %%
from src.utils.metrics_loader import load_metrics
from src.dashboards.visuals import generate_full_dashboard

# %%
data, metrics = load_metrics()

generate_full_dashboard(metrics)
# Out:
# Loading data...
# Computing metrics...
# Generating coverage charts...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 data, metrics = load_metrics()
#       2
# ----> 3 generate_full_dashboard(metrics)
#
# File C:\projects\data-Inspector\src\dashboards\visuals.py:91, in generate_full_dashboard(metrics)
#      87 print("Generating coverage charts...")
#      89 for metric, value in metrics["coverage"].items():
# ---> 91     fig = create_kpi_chart(
#      92         title=metric,
#      93         value=value,
#      94         color="royalblue"
#      95     )
#      97     fig.savefig(
#      98         FIGURES_DIR / "coverage" / clean_filename(metric),
#      99         bbox_inches="tight"
#     100     )
#     102     plt.close(fig)
#
# TypeError: create_kpi_chart() got an unexpected keyword argument 'title'
